# %%
import pandas as pd
import stocks_treemap_slim as sotm

# %% [markdown]
# ## Data acquisition

# %%
excel_df = pd.read_excel('market_stock_value_scoring.xlsx')
excel_df
# Out:
#                             Company Symbol Symbol_Google Symbol_Yahoo  \
# 0                        3M Company    MMM       FRA:MMM        MMM.F
# 1           A. O. Smith Corporation    AOS      NYSE:AOS          AOS
# 2                       AMETEK Inc.    AME      NYSE:AME          AME
# 3                        ANSYS Inc.   ANSS   NASDAQ:ANSS         ANSS
# 4                 ASML Holding N.V.   ASML   NASDAQ:ASML         ASML
# ..                              ...    ...           ...          ...
# 300  Zebra Technologies Corporation   ZBRA   NASDAQ:ZBRA         ZBRA
# 301                       adidas AG    ADS       FRA:ADS        ADS.F
# 302                       eBay Inc.   EBAY   NASDAQ:EBAY         EBAY
# 303        lululemon athletica inc.   LULU   NASDAQ:LULU         LULU
# 304             salesforce.com Inc.    CRM      NYSE:CRM          CRM
#
#                                            Description        Country  \
# ...

# %%
sotm.run(excel_df)
# Out:
#        Industry                   Company Symbol Yahoo Symbol  \
# 0    Technology                Apple Inc.   AAPL         AAPL
# 1            IT     Microsoft Corporation   MSFT         MSFT
# 2            IT             Alphabet Inc.  GOOGL        GOOGL
# 3        Retail           Amazon.com Inc.   AMZN         AMZN
# 4            IT             Facebook Inc.     FB           FB
# ..          ...                       ...    ...          ...
# 300          IT               JD.com Inc.     JD           JD
# 301          IT              NetEase Inc.   NTES         NTES
# 302          IT                Baidu Inc.   BIDU         BIDU
# 303      Retail  lululemon athletica inc.   LULU         LULU
# 304    Software  Tyler Technologies, Inc.    TYL          TYL
#
#                                            Description        Country  \
# 0    Apple Inc. designs, manufactures, and markets ...  United States
# 1    Microsoft Corporation develops, licenses, and ...  United States
# ...
